# %% [markdown]
# # 🚗 Car Sales Report - Data Analysis Project

# %% [markdown]
# 📌 Project Life Cycle - This project follows a structured Data Analysis Life Cycle:
# * Project Definition
# * Define the problem and set clear goals
# * Collect relevant and reliable data
# * Data and Libraries
# * Import necessary Python libraries
# * Load and review the dataset
# * Data Preparation and Cleaning
# * Handle missing values
# * Explore data types and distributions
# * Treat outliers and inconsistencies
# * Interpretation and Visualization
# * Perform univariate and bivariate analysis
# * Visualize key relationships using plots and charts
# * Conclusion
# * Summarize key insights
# * Discuss potential business applications
#
# 📌 Additional :
# 1. Integrating ML models for prediction
# 2. Building Interface using Flask

# %% [markdown]
# 🧭 Project Definition ->
# 🎯 Goal
# To perform a detailed analysis of Car Sales Data to uncover insights, trends, and patterns that can assist in strategic decision-making and improve business outcomes.
#
# 📈 Use Cases -
# * Identify top-performing car brands or models
# * Understand pricing strategies and customer preferences
# * Analyze trends over time for strategic planning
#
# 🔍 Data Source
# The dataset is publicly available on Kaggle: https://www.kaggle.com/datasets/missionjee/car-sales-report/data

# %%
# Library import 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly as pt

import warnings
warnings.filterwarnings("ignore")

# %%
data_path = '/Users/joshi/Desktop/Resume_Projects/Level_01/Car_Sales.csv'
data = pd.read_csv(data_path)

# %%
data.head(5)
# Out:
#          Car_id      Date Customer Name Gender  Annual Income  \
# 0  C_CND_000001  1/2/2022     Geraldine   Male          13500
# 1  C_CND_000002  1/2/2022           Gia   Male        1480000
# 2  C_CND_000003  1/2/2022        Gianna   Male        1035000
# 3  C_CND_000004  1/2/2022       Giselle   Male          13500
# 4  C_CND_000005  1/2/2022         Grace   Male        1465000
#
#                            Dealer_Name   Company       Model  \
# 0  Buddy Storbeck's Diesel Service Inc      Ford  Expedition
# 1                     C & M Motors Inc     Dodge     Durango
# 2                          Capitol KIA  Cadillac    Eldorado
# 3               Chrysler of Tri-Cities    Toyota      Celica
# 4                    Chrysler Plymouth     Acura          TL
#
#                       Engine Transmission       Color  Price ($)  Dealer_No   \
# 0  DoubleÂ Overhead Camshaft         Auto       Black      26000  06457-3834
# ...

# %%
data.tail(5)
# Out:
#              Car_id        Date Customer Name  Gender  Annual Income  \
# 23901  C_CND_023902  12/31/2023        Martin    Male          13500
# 23902  C_CND_023903  12/31/2023         Jimmy  Female         900000
# 23903  C_CND_023904  12/31/2023          Emma    Male         705000
# 23904  C_CND_023905  12/31/2023      Victoire    Male          13500
# 23905  C_CND_023906  12/31/2023       Donovan    Male        1225000
#
#                           Dealer_Name    Company    Model  \
# 23901                C & M Motors Inc   Plymouth  Voyager
# 23902  Ryder Truck Rental and Leasing  Chevrolet    Prizm
# 23903          Chrysler of Tri-Cities        BMW     328i
# 23904               Chrysler Plymouth  Chevrolet    Metro
# 23905                 Pars Auto Sales      Lexus    ES300
#
#                           Engine Transmission       Color  Price ($)  \
# 23901          Overhead Camshaft       Manual         Red      12000
# ...

# %%
data.shape
# Out:
# (23906, 16)

# %% [markdown]
# 🧹 Data Preparation and Cleaning - In this stage, we ensure the dataset is clean, consistent, and ready for analysis. The following steps will be carried out:
#
# 1. 🔍 Check for Missing Values
# 2. 🧬 Check for Duplicates
# 3. 🧾 Check Data Types
# 4. 🔢 Check Number of Unique Values per Column
# 5. 📊 Summary Statistics
# 6. 🏷️ Explore Categories in Categorical Columns

# %%
data.isna().sum()
# Out:
# Car_id           0
# Date             0
# Customer Name    1
# Gender           0
# Annual Income    0
# Dealer_Name      0
# Company          0
# Model            0
# Engine           0
# Transmission     0
# Color            0
# Price ($)        0
# Dealer_No        0
# Body Style       0
# Phone            0
# Dealer_Region    0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23906 entries, 0 to 23905
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_id         23906 non-null  object
#  1   Date           23906 non-null  object
#  2   Customer Name  23905 non-null  object
#  3   Gender         23906 non-null  object
#  4   Annual Income  23906 non-null  int64
#  5   Dealer_Name    23906 non-null  object
#  6   Company        23906 non-null  object
#  7   Model          23906 non-null  object
#  8   Engine         23906 non-null  object
#  9   Transmission   23906 non-null  object
#  10  Color          23906 non-null  object
#  11  Price ($)      23906 non-null  int64
#  12  Dealer_No      23906 non-null  object
#  13  Body Style     23906 non-null  object
#  14  Phone          23906 non-null  int64
#  15  Dealer_Region  23906 non-null  object
# dtypes: int64(3), object(13)
# memory usage: 2.9+ MB

# %%
data.nunique()
# Out:
# Car_id           23906
# Date               612
# Customer Name     3021
# Gender               2
# Annual Income     2508
# Dealer_Name         28
# Company             30
# Model              154
# Engine               2
# Transmission         2
# Color                3
# Price ($)          870
# Dealer_No            7
# Body Style           5
# Phone            23804
# Dealer_Region        7
# dtype: int64

# %%
data.describe().T
# Out:
#                  count          mean            std        min        25%  \
# Annual Income  23906.0  8.308403e+05  720006.395388    10080.0   386000.0
# Price ($)      23906.0  2.809025e+04   14788.687608     1200.0    18001.0
# Phone          23906.0  7.497741e+06  867491.995669  6000101.0  6746495.0
#
#                      50%         75%         max
# Annual Income   735000.0  1175750.00  11200000.0
# Price ($)        23000.0    34000.00     85800.0
# Phone          7496197.5  8248146.25   8999579.0

# %% [markdown]
# * There are no missing values in the dataset
# * There is no duplicate data
# * There are 3 int64 and 13 object type features present
# * If we see there must be some people who purched more cars as they have same number : Since, Unique Car_id != Unique Phone
# * The Maximum Price of car is = 858000$
# * The Minimum Price of car is = 1200$
# * Types of Engines = 2, Color = 3 and Body Styles = 5

# %%
# Checking the categories of the categorical features:
print("The categories in the variable 'Gender': ",end=" ")
print(data['Gender'].unique())

print("The categories in the variable 'Company': ",end=" ")
print(data['Company'].unique())

print("The categories in the variable 'Engine': ",end=" ")
print(data['Engine'].unique())

print("The categories in the variable 'Transmission': ",end=" ")
print(data['Transmission'].unique())

print("The categories in the variable 'Color': ",end=" ")
print(data['Color'].unique())

print("The categories in the variable 'Body Style': ",end=" ")
print(data['Body Style'].unique())

print("The categories in the variable 'Dealer_Region': ",end=" ")
print(data['Dealer_Region'].unique())
# Out:
# The categories in the variable 'Gender':  ['Male' 'Female']
# The categories in the variable 'Company':  ['Ford' 'Dodge' 'Cadillac' 'Toyota' 'Acura' 'Mitsubishi' 'Chevrolet'
#  'Nissan' 'Mercury' 'BMW' 'Chrysler' 'Subaru' 'Hyundai' 'Honda' 'Infiniti'
#  'Audi' 'Porsche' 'Volkswagen' 'Buick' 'Saturn' 'Mercedes-B' 'Jaguar'
#  'Volvo' 'Pontiac' 'Lincoln' 'Oldsmobile' 'Lexus' 'Plymouth' 'Saab' 'Jeep']
# The categories in the variable 'Engine':  ['DoubleÂ\xa0Overhead Camshaft' 'Overhead Camshaft']
# The categories in the variable 'Transmission':  ['Auto' 'Manual']
# The categories in the variable 'Color':  ['Black' 'Red' 'Pale White']
# The categories in the variable 'Body Style':  ['SUV' 'Passenger' 'Hatchback' 'Hardtop' 'Sedan']
# The categories in the variable 'Dealer_Region':  ['Middletown' 'Aurora' 'Greenville' 'Pasco' 'Janesville' 'Scottsdale'
#  'Austin']

# %%
# This specific type of Engine name is 'DoubleÂ\xa0Overhead Camshaft' -> 'Double Overhead Camshaft'
print(data['Engine'].value_counts()['DoubleÂ\xa0Overhead Camshaft'])

# Replace occurrences
data['Engine'] = data['Engine'].replace('DoubleÂ\xa0Overhead Camshaft', 'Double Overhead Camshaft')

# Confirming the replacement
print(data['Engine'].unique())
# Out:
# 12571
# ['Double Overhead Camshaft' 'Overhead Camshaft']

# %%
# Now, defining Numerical and Categorical Features :
num_feature = [feature for feature in data.columns if data[feature].dtype != 'O']

cat_feature = [feature for feature in data.columns if data[feature].dtype == 'O']

# Names of Numeric and Categorical Features :
print('We have {} numerical features : {}'.format(len(num_feature), num_feature))
print('We have {} categorical features : {}'.format(len(cat_feature), cat_feature))
# Out:
# We have 3 numerical features : ['Annual Income', 'Price ($)', 'Phone']
# We have 13 categorical features : ['Car_id', 'Date', 'Customer Name', 'Gender', 'Dealer_Name', 'Company', 'Model', 'Engine', 'Transmission', 'Color', 'Dealer_No ', 'Body Style', 'Dealer_Region']

# %%
drop_col = ['Phone','Car_id','Customer Name','Dealer_Name','Dealer_No ']
df = data.drop(drop_col,axis=1)

# %%
df.head()
# Out:
#        Date Gender  Annual Income   Company       Model  \
# 0  1/2/2022   Male          13500      Ford  Expedition
# 1  1/2/2022   Male        1480000     Dodge     Durango
# 2  1/2/2022   Male        1035000  Cadillac    Eldorado
# 3  1/2/2022   Male          13500    Toyota      Celica
# 4  1/2/2022   Male        1465000     Acura          TL
#
#                      Engine Transmission       Color  Price ($) Body Style  \
# 0  Double Overhead Camshaft         Auto       Black      26000        SUV
# 1  Double Overhead Camshaft         Auto       Black      19000        SUV
# 2         Overhead Camshaft       Manual         Red      31500  Passenger
# 3         Overhead Camshaft       Manual  Pale White      14000        SUV
# 4  Double Overhead Camshaft         Auto         Red      24500  Hatchback
#
#   Dealer_Region
# 0    Middletown
# 1        Aurora
# 2    Greenville
# 3         Pasco
# 4    Janesville

# %% [markdown]
# 📈📊 Data Visualization and Interpretation :
# * Graphs
# * Plots
# * Realtional Graphs
# * Univariate and Bivariate Analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23906 entries, 0 to 23905
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           23906 non-null  object
#  1   Gender         23906 non-null  object
#  2   Annual Income  23906 non-null  int64
#  3   Company        23906 non-null  object
#  4   Model          23906 non-null  object
#  5   Engine         23906 non-null  object
#  6   Transmission   23906 non-null  object
#  7   Color          23906 non-null  object
#  8   Price ($)      23906 non-null  int64
#  9   Body Style     23906 non-null  object
#  10  Dealer_Region  23906 non-null  object
# dtypes: int64(2), object(9)
# memory usage: 2.0+ MB

# %%
df.head()
# Out:
#        Date Gender  Annual Income   Company       Model  \
# 0  1/2/2022   Male          13500      Ford  Expedition
# 1  1/2/2022   Male        1480000     Dodge     Durango
# 2  1/2/2022   Male        1035000  Cadillac    Eldorado
# 3  1/2/2022   Male          13500    Toyota      Celica
# 4  1/2/2022   Male        1465000     Acura          TL
#
#                      Engine Transmission       Color  Price ($) Body Style  \
# 0  Double Overhead Camshaft         Auto       Black      26000        SUV
# 1  Double Overhead Camshaft         Auto       Black      19000        SUV
# 2         Overhead Camshaft       Manual         Red      31500  Passenger
# 3         Overhead Camshaft       Manual  Pale White      14000        SUV
# 4  Double Overhead Camshaft         Auto         Red      24500  Hatchback
#
#   Dealer_Region
# 0    Middletown
# 1        Aurora
# 2    Greenville
# 3         Pasco
# 4    Janesville

# %%
fig, axs = plt.subplots(1, 2, figsize=(15, 7))
plt.subplot(121)
sns.histplot(data=df,x='Annual Income',bins=12,kde=True,color='g')
plt.subplot(122)
sns.histplot(data=df,x='Annual Income',bins=12,kde=True,hue='Gender')
plt.show()

# %%
min_salary = df['Annual Income'].min()
max_salary = df['Annual Income'].max()
print("The minimum salary (Annual) of a person that bought the car = {}".format(min_salary))
print("The maximum salary (Annual) of a person that bought the car = {}".format(max_salary))
# Out:
# The minimum salary (Annual) of a person that bought the car = 10080
# The maximum salary (Annual) of a person that bought the car = 11200000

# %%
sns.countplot(data=df,x='Gender',color='skyblue')
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
fig, axs = plt.subplots(1, 1, figsize=(10, 5))
plt.subplot(111)
sns.histplot(data=df,x='Price ($)',bins=12,kde=True,color='teal')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(data=df,y='Company',palette = 'pastel')
# Out:
# <Axes: xlabel='count', ylabel='Company'>

# %%
plt.figure(figsize=(10, 24))
sns.countplot(data=df,y='Model',palette = 'pastel')
# Out:
# <Axes: xlabel='count', ylabel='Model'>

# %%
plt.figure(figsize=(5, 4))
sns.countplot(data=df,x='Engine',palette='husl')
# Out:
# <Axes: xlabel='Engine', ylabel='count'>

# %%
plt.figure(figsize=(5, 5))
sns.countplot(data=df,x='Transmission',palette = 'Blues')
# Out:
# <Axes: xlabel='Transmission', ylabel='count'>

# %%
plt.figure(figsize=(5, 5))
sns.countplot(data=df,x='Color',palette = 'flare')
# Out:
# <Axes: xlabel='Color', ylabel='count'>

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 6))
plt.subplot(121)
sns.histplot(data=df,x='Body Style',color='skyblue')
plt.subplot(122)
sns.histplot(data=df,x='Body Style',hue='Gender')
plt.show()

# %%
plt.figure(figsize=(7, 5))
sns.countplot(data=df,x='Dealer_Region',palette = 'Blues')
# Out:
# <Axes: xlabel='Dealer_Region', ylabel='count'>

# %%
sns.scatterplot(data=df,x='Price ($)',y='Transmission',hue='Transmission')
# Out:
# <Axes: xlabel='Price ($)', ylabel='Transmission'>

# %%
plt.figure(figsize=(10, 10))
sns.pairplot(data=df,hue='Gender',kind='scatter',diag_kind='hist')

# %%
plt.figure(figsize=(5, 5))
sns.jointplot(data=df,x='Annual Income',y='Price ($)',hue='Transmission')

# %%
plt.figure(figsize=(5, 5))
sns.jointplot(data=df,x='Price ($)',y='Annual Income',hue='Color',marker='^')

# %%
sns.boxplot(data=df, x="Price ($)", y="Body Style",hue='Body Style',palette = 'crest')
# Out:
# <Axes: xlabel='Price ($)', ylabel='Body Style'>

# %%
sns.boxplot(data=df, x="Price ($)", y="Engine",hue='Engine',palette = 'viridis')
# Out:
# <Axes: xlabel='Price ($)', ylabel='Engine'>

# %% [markdown]
# 📈📊 Advance Visualization and Insights (Time Series)
# 1. Relation of other columns with time
# 2. Analysis of trend
# 3. Visualizations

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.holtwinters import ExponentialSmoothing
df.head()
# Out:
#        Date Gender  Annual Income   Company       Model  \
# 0  1/2/2022   Male          13500      Ford  Expedition
# 1  1/2/2022   Male        1480000     Dodge     Durango
# 2  1/2/2022   Male        1035000  Cadillac    Eldorado
# 3  1/2/2022   Male          13500    Toyota      Celica
# 4  1/2/2022   Male        1465000     Acura          TL
#
#                      Engine Transmission       Color  Price ($) Body Style  \
# 0  Double Overhead Camshaft         Auto       Black      26000        SUV
# 1  Double Overhead Camshaft         Auto       Black      19000        SUV
# 2         Overhead Camshaft       Manual         Red      31500  Passenger
# 3         Overhead Camshaft       Manual  Pale White      14000        SUV
# 4  Double Overhead Camshaft         Auto         Red      24500  Hatchback
#
#   Dealer_Region
# 0    Middletown
# 1        Aurora
# 2    Greenville
# 3         Pasco
# 4    Janesville

# %%
# Made a copy for the analysis :
df_samp = df.copy()
df_samp.head(2)
# Out:
#        Date Gender  Annual Income Company       Model  \
# 0  1/2/2022   Male          13500    Ford  Expedition
# 1  1/2/2022   Male        1480000   Dodge     Durango
#
#                      Engine Transmission  Color  Price ($) Body Style  \
# 0  Double Overhead Camshaft         Auto  Black      26000        SUV
# 1  Double Overhead Camshaft         Auto  Black      19000        SUV
#
#   Dealer_Region
# 0    Middletown
# 1        Aurora

# %%
# Parsing Date and setting as index : 
df_samp['Date'] = pd.to_datetime(df_samp['Date'], format="%m/%d/%Y")
df_samp.set_index('Date', inplace=True)

# %%
# Adding a “Units_Sold” column (one sale per row)
df_samp['Units_Sold'] = 1

# %%
# Quickly checking the data
print(df_samp.index.min(), df_samp.index.max())
# Out:
# 2022-01-02 00:00:00 2023-12-31 00:00:00

# %%
df_samp.head()
# Out:
#            Gender  Annual Income   Company       Model  \
# Date
# 2022-01-02   Male          13500      Ford  Expedition
# 2022-01-02   Male        1480000     Dodge     Durango
# 2022-01-02   Male        1035000  Cadillac    Eldorado
# 2022-01-02   Male          13500    Toyota      Celica
# 2022-01-02   Male        1465000     Acura          TL
#
#                               Engine Transmission       Color  Price ($)  \
# Date
# 2022-01-02  Double Overhead Camshaft         Auto       Black      26000
# 2022-01-02  Double Overhead Camshaft         Auto       Black      19000
# 2022-01-02         Overhead Camshaft       Manual         Red      31500
# 2022-01-02         Overhead Camshaft       Manual  Pale White      14000
# 2022-01-02  Double Overhead Camshaft         Auto         Red      24500
#
#            Body Style Dealer_Region  Units_Sold
# Date
# 2022-01-02        SUV    Middletown           1
# 2022-01-02        SUV        Aurora           1
# ...

# %%
# Daily + Weekly + Monthly Aggregation :
# Daily totals
daily = df_samp.resample('D').agg({
    'Units_Sold': 'sum',
    'Price ($)': 'sum'
}).rename(columns={'Price ($)': 'Daily_Revenue'})

# Weekly totals (Mon–Sun)
weekly = df_samp.resample('W').agg({
    'Units_Sold': 'sum',
    'Price ($)': 'sum'
}).rename(columns={'Price ($)': 'Weekly_Revenue'})

# Monthly totals
monthly = df_samp.resample('M').agg({
    'Units_Sold': 'sum',
    'Price ($)': 'sum'
}).rename(columns={'Price ($)': 'Monthly_Revenue'})

# Yearly totals
yearly = df_samp.resample('Y').agg({
    'Units_Sold': 'sum',
    'Price ($)': 'sum'
}).rename(columns={'Price ($)': 'Yearly_Revenue'})

# Inspect
print(daily.head(), weekly.head(), monthly.head(), yearly.head(), sep="\n\n")
# Out:
#             Units_Sold  Daily_Revenue
# Date
# 2022-01-02          35         882250
# 2022-01-03          20         575503
# 2022-01-04          15         393700
# 2022-01-05          30         938103
# 2022-01-06          10         303202
#
#             Units_Sold  Weekly_Revenue
# Date
# 2022-01-02          35          882250
# 2022-01-09          95         2869262
# 2022-01-16          55         1533453
# 2022-01-23          65         1787703
# 2022-01-30          50         1371402
#
#             Units_Sold  Monthly_Revenue
# Date
# 2022-01-31         315          8931920
# 2022-02-28         320          8795365
# 2022-03-31         705         19502059
# 2022-04-30         800         22748867
# 2022-05-31         750         20608086
#
#             Units_Sold  Yearly_Revenue
# Date
# 2022-12-31       10645       300340345
# 2023-12-31       13261       371185120

# %%
# Plotting the Aggregation :
plt.figure(figsize=(12,4))
plt.plot(daily['Units_Sold'], label='Daily Units Sold')
plt.plot(weekly['Units_Sold'], label='Weekly Units Sold', alpha=0.8)
plt.plot(monthly['Units_Sold'], label='Monthly Units Sold', linewidth=2)
plt.legend(); plt.title("Units Sold Over Time")
plt.show()

plt.figure(figsize=(12,4))
plt.plot(daily['Daily_Revenue'], label='Daily Revenue')
plt.plot(weekly['Weekly_Revenue'], label='Weekly Revenue', alpha=0.8)
plt.plot(monthly['Monthly_Revenue'], label='Monthly Revenue', linewidth=2)
plt.legend(); plt.title("Revenue Over Time")
plt.show()

# %%
# Seasonality and Trend Decomposition :
# Decompose the monthly revenue into trend, seasonality, residual
decomp = seasonal_decompose(monthly['Monthly_Revenue'], model='additive')
decomp.plot()
plt.suptitle("Additive Decomposition of Monthly Revenue", y=1.02)
plt.show()

# %%
# A basic monthly forecast (Using Holt-Winters)
# Fit Holt-Winters on monthly revenue
hw_model = ExponentialSmoothing(
    monthly['Monthly_Revenue'],
    trend='add',
    seasonal='add',
    seasonal_periods=12
).fit()

# Forecast next 6 months
forecast = hw_model.forecast(4)

# Combine for plotting
proj = pd.concat([monthly['Monthly_Revenue'], forecast], axis=0)

plt.figure(figsize=(10,4))
plt.plot(monthly['Monthly_Revenue'], label='Historical')
plt.plot(forecast, label='Forecast', linestyle='--', marker='o')
plt.title("3-Month Revenue Forecast (Holt–Winters)")
plt.legend()
plt.show()

# %%
# Define train / test split (last 4 months as hold-out)
train = monthly['Monthly_Revenue'][:-4]
test  = monthly['Monthly_Revenue'][-4:]

# 2. Re-fit Holt–Winters with a 4-month seasonality
hw4 = ExponentialSmoothing(
    train,
    trend='add',
    seasonal='add',
    seasonal_periods=4
).fit()

# 3. Forecast over the test period
hw4_pred = hw4.forecast(len(test))

# 4. Compute metrics
mape_hw4 = mean_absolute_percentage_error(test, hw4_pred)
rmse_hw4 = np.sqrt(mean_squared_error(test, hw4_pred))

print(f"Holt-Winters (4-month seasonality) → MAPE: {mape_hw4:.2%},  RMSE: {rmse_hw4:.2f}")
# Out:
# Holt-Winters (4-month seasonality) → MAPE: 34.45%,  RMSE: 18281532.87

# %%
from statsmodels.tsa.arima.model import ARIMA

# Example: SARIMA(1,1,1)x(1,1,1,12)
sarima = ARIMA(train,
               order=(1,1,1),
               seasonal_order=(1,1,1,12)
              ).fit()

# Forecast
sarima_pred = sarima.forecast(len(test))

# Metrics
mape_sar = mean_absolute_percentage_error(test, sarima_pred)
rmse_sar = np.sqrt(mean_squared_error(test, sarima_pred))

print(f"SARIMA(1,1,1)x(1,1,1,12) → MAPE: {mape_sar:.2%},  RMSE: {rmse_sar:.2f}")
# Out:
# SARIMA(1,1,1)x(1,1,1,12) → MAPE: 25.67%,  RMSE: 15268358.77

# %%
plt.figure(figsize=(10,4))
plt.plot(train.index, train, label='Train')
plt.plot(test.index, test, 'o-', label='Actual')
plt.plot(test.index, forecast,   's--', label='HW Forecast')
plt.plot(test.index, sarima_pred,'v--', label='Manual SARIMA')
plt.title("Hold-out Forecast Comparison")
plt.legend(); plt.show()

# %%
# Top Brands & Models by Sales Volume and Revenue
# 1. Aggregate by Company
brand_summary = (
    df_samp
    .groupby('Company')
    .agg(
        Units_Sold=('Units_Sold', 'sum'),
        Total_Revenue=('Price ($)', 'sum')
    )
    .sort_values(by='Units_Sold', ascending=False)
)

print("Top Brands by Units Sold & Revenue:")
print(brand_summary.head(10))

# 2. Aggregate by Company + Model
model_summary = (
    df_samp
    .groupby(['Company', 'Model'])
    .agg(
        Units_Sold=('Units_Sold', 'sum'),
        Total_Revenue=('Price ($)', 'sum')
    )
    .sort_values(by='Units_Sold', ascending=False)
)

print("\nTop Models by Units Sold & Revenue:")
print(model_summary.head(10))
# Out:
# Top Brands by Units Sold & Revenue:
#             Units_Sold  Total_Revenue
# Company
# Chevrolet         1819       47655265
# Dodge             1671       44124996
# Ford              1614       47231583
# Volkswagen        1333       34082881
# Mercedes-B        1285       34624123
# Mitsubishi        1277       34062466
# Chrysler          1120       29141873
# Oldsmobile        1111       35434512
# Toyota            1110       32759564
# Nissan             886       23964095
#
# Top Models by Units Sold & Revenue:
#                        Units_Sold  Total_Revenue
# Company    Model
# Mitsubishi Diamante           418        9308151
# Oldsmobile Silhouette         411       12271849
# Chevrolet  Prizm              411        9386606
# Volkswagen Passat             391        7663885
# Dodge      Ram Pickup         383       10655391
# Volkswagen Jetta              382       12287736
# Acura      RL                 372        8778638
# ...

# %%
# Engine & Transmission Mix (% Share)
# 1. Engine type mix
engine_mix = (
    df_samp['Engine'] 
    .value_counts(normalize=True)
    .mul(100)
    .rename("Pct_Share")
)

print("Engine Type % Share:")
print(engine_mix)

# 2. Transmission mix
trans_mix = (
    df_samp['Transmission']  # e.g. 'Automatic' vs. 'Manual'
    .value_counts(normalize=True)
    .mul(100)
    .rename("Pct_Share")
)

print("\nTransmission % Share:")
print(trans_mix)
# Out:
# Engine Type % Share:
# Engine
# Double Overhead Camshaft    52.585125
# Overhead Camshaft           47.414875
# Name: Pct_Share, dtype: float64
#
# Transmission % Share:
# Transmission
# Auto      52.585125
# Manual    47.414875
# Name: Pct_Share, dtype: float64

# %%
# 1. Color preferences
color_counts = df['Color'].value_counts()
plt.figure(figsize=(8,4))
plt.bar(color_counts.index, color_counts.values)
plt.xticks(rotation=45, ha='right')
plt.title("Car Color Preferences")
plt.ylabel("Units Sold")
plt.tight_layout()
plt.show()

# 2. Body Style preferences
body_counts = df['Body Style'].value_counts()
plt.figure(figsize=(8,4))
plt.bar(body_counts.index, body_counts.values)
plt.xticks(rotation=45, ha='right')
plt.title("Body Style Preferences")
plt.ylabel("Units Sold")
plt.tight_layout()
plt.show()

# %% [markdown]
# 📈📊 Building a Machine Learning Prediction model for Price Prediction

# %%
df.head()
# Out:
#        Date Gender  Annual Income   Company       Model  \
# 0  1/2/2022   Male          13500      Ford  Expedition
# 1  1/2/2022   Male        1480000     Dodge     Durango
# 2  1/2/2022   Male        1035000  Cadillac    Eldorado
# 3  1/2/2022   Male          13500    Toyota      Celica
# 4  1/2/2022   Male        1465000     Acura          TL
#
#                      Engine Transmission       Color  Price ($) Body Style  \
# 0  Double Overhead Camshaft         Auto       Black      26000        SUV
# 1  Double Overhead Camshaft         Auto       Black      19000        SUV
# 2         Overhead Camshaft       Manual         Red      31500  Passenger
# 3         Overhead Camshaft       Manual  Pale White      14000        SUV
# 4  Double Overhead Camshaft         Auto         Red      24500  Hatchback
#
#   Dealer_Region
# 0    Middletown
# 1        Aurora
# 2    Greenville
# 3         Pasco
# 4    Janesville
